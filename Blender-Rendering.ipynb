# %% [markdown]
# <a href="https://colab.research.google.com/github/AstroNaut244/blender-colab/blob/master/Blender-Rendering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
# **Make sure to read the instructions carefully!**
#
# If you have other resources used in the Blender project and chose to *make all paths relative*, pack all of them into a zip archive. Alternatively, you can *pack all external file*.
#
# * `blender_version` : Version of blender used to render the scene. Only supports 2.8x
# * `blend_file_path` : Path to the blend file after unpacking the zip archive. If blend file is used, this is automatically ignored.
# ___
# * `upload_type` : Select the type of upload method. `gdrive_relative` pulls everything from the folder specified.
# * `drive_path` : Path to your blend/zip file relative to the root of your Google Drive if `google_drive` is selected. Must  state the file and its extension (.zip/.blend) **unless** `gdrive_relative` is selected.
# * `url_blend` : Specify the URL to the blend/zip file if `url` is selected.
# ___
# * `animation` : Specify whether animation or still image is rendered. If **still image** is used, put the frame number in `start_frame`.
# * `start_frame, end_frame` : Specify the start and end frame for animation. You may put same value such as zero for both input to set the default frame in the blend file.
# ___
# * `download_type` : Select the type of download method. `gdrive_direct` enables the frames to be outputted directly to Google Drive (zipping will be disabled).
# * `output_name` : Name of the output frames, **do NOT include .blend!** (## for frame number)
# * `zip_files` : Archive multiple animation frames automatically into a zip file.
# * `drive_output_path` : Path to your frames/zip file in Google Drive.
# ___
# * `gpu_enabled, cpu_enabled` : Toggle GPU and CPU for rendering. CPU might give a slight boost in rendering time but may varies depend on the project.
#
# After you are done, go to Runtime > Run All (Ctrl + F9) and upload your files or have Google Drive authorised below. See the [GitHub repo](https://github.com/syn73/blender-colab) for more info.

# %%
#@markdown #**Check GPU type**
#@markdown ### Factory reset runtime if you don't have the desired GPU.

#@markdown ---




#@markdown V100 = Very Very fast rendering (*Available only for Colab Pro users*)

#@markdown P100 = Faster rendering

#@markdown T4 = Fast rendering

#@markdown K80 = 2x Slower rendering compared to T4

#@markdown P4 = Very slow, not recommended

#@markdown ---

# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-45de04c5-706c-3d8b-46d5-c099f8bbed31)

# %%
#@title Now choose your rendering options. You dont really need to change the file path; just choose your upload and download type, run the cell, then go to the next cell to upload your file. If you choose direct upload, you can directly upload your file in the next cell. If your project is an animation, dont forget to enable "animation", if not it will render only a single frame
blender_version = '3.0.0 alpha cycles-x' #@param ['2.79b', '2.80rc3', '2.81a', '2.82a', '2.83.16', '2.90.1', '2.91.2', '2.92.0', '2.93.1', '2.93.3', '3.0.0 aplha', '3.0.0 alpha cycles-x'] {allow-input: false}
blend_file_path = 'path/to/file.blend' #@param {type: 'string'}
#@markdown ---
upload_type = 'direct' #@param ['direct', 'google_drive', 'url', 'gdrive_relative'] {allow-input: false}
drive_path = 'path/to/blend.zip' #@param {type: 'string'}
url_blend = '' #@param {type: 'string'}
#@markdown ---
animation = False #@param {type: 'boolean'}
start_frame =  1#@param {type: 'integer'}
end_frame =  250#@param {type: 'integer'}
#@markdown ---
download_type = 'direct' #@param ['direct', 'google_drive', 'gdrive_direct'] {allow-input: false}
output_name = 'blender-##' #@param {type: 'string'}
zip_files = True #@param {type: 'boolean'}
drive_output_path = 'blender/output' #@param {type: 'string'}
#@markdown ---
gpu_enabled = True #@param {type:"boolean"}
cpu_enabled = False #@param {type:"boolean"}

# %%
#@title Run this cell to upload your file with the selected method
import os
import shutil
from google.colab import files, drive
uploaded_filename = ""

if upload_type == 'google_drive' or upload_type == 'gdrive_relative' or download_type == 'google_drive' or download_type == 'gdrive_direct':
    drive.mount('/drive')

if upload_type == 'direct':
    uploaded = files.upload()
    for fn in uploaded.keys():
        uploaded_filename = fn
elif upload_type == 'url':
    # !wget -nc $url_blend
    uploaded_filename = os.path.basename(url_blend)
elif upload_type == 'google_drive':
    shutil.copy('/drive/My Drive/' + drive_path, '.')
    uploaded_filename = os.path.basename(drive_path)

    # !rm -r render
# !mkdir render

if upload_type == 'gdrive_relative':
    if not drive_path.endswith('/'):
        drive_path += '/'
    # !cp -r '/drive/My Drive/{drive_path}.' 'render/'
elif uploaded_filename.lower().endswith('.zip'):
    # !unzip -o $uploaded_filename -d 'render/'
elif uploaded_filename.lower().endswith('.blend'):
    shutil.copy(uploaded_filename, 'render/')
    blend_file_path = uploaded_filename
else:
    raise SystemExit("Invalid file extension, only .blend and .zip can be uploaded.")
# Out:
#      <input type="file" id="files-00c42e85-3374-4511-9a60-168686a758d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00c42e85-3374-4511-9a60-168686a758d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3D hand.blend to 3D hand.blend

# %%
#@title Download blender

blender_url_dict = {'2.79b'   : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.79/blender-2.79b-linux-glibc219-x86_64.tar.bz2",
                    '2.80rc3' : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.80/blender-2.80rc3-linux-glibc217-x86_64.tar.bz2",
                    '2.81a'   : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.81/blender-2.81a-linux-glibc217-x86_64.tar.bz2",
                    '2.82a'   : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.82/blender-2.82a-linux64.tar.xz",
                    '2.83.16' : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.83/blender-2.83.16-linux-x64.tar.xz",
                    '2.90.1'  : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.90/blender-2.90.1-linux64.tar.xz",
                    '2.91.2'  : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.91/blender-2.91.2-linux64.tar.xz",
                    '2.92.0'  : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.92/blender-2.92.0-linux64.tar.xz",
                    '2.93.1'  : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.93/blender-2.93.1-linux-x64.tar.xz",
                    '2.93.3'  : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.93/blender-2.93.3-linux-x64.tar.xz",
                    '3.0.0 alpha'  : "https://builder.blender.org/download/daily/blender-3.0.0-alpha+master.7d17f2addf80-linux.x86_64-release.tar.xz",
                    '3.0.0 alpha cycles-x'  : "https://builder.blender.org/download/experimental/blender-3.0.0-alpha+cycles-x.6ff8b06fe770-linux.x86_64-release.tar.xz"}

blender_url = blender_url_dict[blender_version]
base_url = os.path.basename(blender_url)

# !mkdir $blender_version
# !wget -nc $blender_url
# !tar -xkf $base_url -C ./$blender_version --strip-components=1
# Out:
# --2021-08-23 16:35:54--  https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.93/blender-2.93.1-linux-x64.tar.xz
# Resolving ftp.nluug.nl (ftp.nluug.nl)... 145.220.21.40, 2001:67c:6ec:221:145:220:21:40
# Connecting to ftp.nluug.nl (ftp.nluug.nl)|145.220.21.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 166685444 (159M) [application/x-tar]
# Saving to: ‘blender-2.93.1-linux-x64.tar.xz’
#
# blender-2.93.1-linu 100%[===================>] 158.96M  21.0MB/s    in 10s
#
# 2021-08-23 16:36:05 (15.5 MB/s) - ‘blender-2.93.1-linux-x64.tar.xz’ saved [166685444/166685444]

# %%
#@title Enable GPU rendering (or add custom properties by double clicking here)
data = "import re\n"+\
    "import bpy\n"+\
    "scene = bpy.context.scene\n"+\
    "scene.cycles.device = 'GPU'\n"+\
    "prefs = bpy.context.preferences\n"+\
    "prefs.addons['cycles'].preferences.get_devices()\n"+\
    "cprefs = prefs.addons['cycles'].preferences\n"+\
    "print(cprefs)\n"+\
    "for compute_device_type in ('CUDA', 'OPENCL', 'NONE'):\n"+\
    "    try:\n"+\
    "        cprefs.compute_device_type = compute_device_type\n"+\
    "        print('Device found:',compute_device_type)\n"+\
    "        break\n"+\
    "    except TypeError:\n"+\
    "        pass\n"+\
    "for device in cprefs.devices:\n"+\
    "    if not re.match('intel', device.name, re.I):\n"+\
    "        print('Activating',device)\n"+\
    "        device.use = "+str(gpu_enabled)+"\n"+\
    "    else:\n"+\
    "        device.use = "+str(cpu_enabled)+"\n"
with open('setgpu.py', 'w') as f:
    f.write(data)

# %%
#@title Start rendering!
# !rm -r output
# !mkdir output

if not drive_output_path.endswith('/'):
    drive_output_path += '/'

if download_type != 'gdrive_direct':
    output_path = 'output/' + output_name
else:
    output_path = '/drive/My Drive/' + drive_output_path + output_name

if animation:
    if start_frame == end_frame:
        # !sudo ./$blender_version/blender -b 'render/{blend_file_path}' -P setgpu.py -E CYCLES -o '{output_path}' -noaudio -a
    else:
        # !sudo ./$blender_version/blender -b 'render/{blend_file_path}' -P setgpu.py -E CYCLES -o '{output_path}' -noaudio -s $start_frame -e $end_frame -a
else:
    # !sudo ./$blender_version/blender -b 'render/{blend_file_path}' -P setgpu.py -E CYCLES -o '{output_path}' -noaudio -f $start_frame
# Out:
# rm: cannot remove 'output': No such file or directory
# Blender 2.93.1 (hash 1b8d33b18c2f built 2021-06-22 23:38:50)
# Read blend: /content/render/3D hand.blend
# <bpy_struct, CyclesPreferences at 0x7f7411c1f448>
# Device found: CUDA
# Activating <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7f741227e108>
# Activating <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7f741227e208>
# Fra:1 Mem:117.22M (Peak 123.31M) | Time:00:00.46 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Hand_3D.003
# Fra:1 Mem:118.16M (Peak 123.31M) | Time:00:00.46 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Hand_3D
# Fra:1 Mem:133.55M (Peak 138.48M) | Time:00:00.66 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Hand_3D.002
# Fra:1 Mem:140.66M (Peak 143.47M) | Time:00:00.84 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Initializing
# Fra:1 Mem:123.69M (Peak 143.47M) | Time:00:00.84 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Images | Loading Hand_3D_COLOR.jpg
# Fra:1 Mem:123.69M (Peak 143.47M) | Time:00:00.84 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Images | Loading Hand_3D_NRM.jpg
# Fra:1 Mem:315.71M (Peak 507.71M) | Time:00:01.40 | Mem:64.00M, Peak:64.00M | Scene, RenderLayer | Updating Images | Loading Hand_3D_BUMP.jpg
# Fra:1 Mem:443.71M (Peak 507.71M) | Time:00:01.55 | Mem:128.00M, Peak:128.00M | Scene, RenderLayer | Updating Images | Loading Hand_3D_SPEC.jpg
# Fra:1 Mem:379.21M (Peak 635.72M) | Time:00:01.80 | Mem:256.00M, Peak:256.00M | Scene, RenderLayer | Waiting for render to start
# Fra:1 Mem:379.36M (Peak 635.72M) | Time:00:01.80 | Mem:256.00M, Peak:256.00M | Scene, RenderLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:379.36M (Peak 635.72M) | Time:00:01.85 | Mem:256.00M, Peak:256.00M | Scene, RenderLayer | Updating Scene
# Fra:1 Mem:379.36M (Peak 635.72M) | Time:00:01.85 | Mem:256.00M, Peak:256.00M | Scene, RenderLayer | Updating Shaders
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Procedurals
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Background
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Camera
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Meshes Flags
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Objects
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Particle Systems
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:379.87M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Meshes
# Fra:1 Mem:382.69M (Peak 635.72M) | Time:00:01.95 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:398.90M (Peak 635.72M) | Time:00:01.96 | Mem:256.01M, Peak:256.01M | Scene, RenderLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:398.90M (Peak 635.72M) | Time:00:01.97 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane 3/3 | Building BVH
# Fra:1 Mem:398.90M (Peak 635.72M) | Time:00:01.97 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.004 1/3 | Building BVH
# Fra:1 Mem:405.94M (Peak 635.72M) | Time:00:02.05 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.004 1/3 | Packing BVH triangles and strands
# Fra:1 Mem:409.23M (Peak 635.72M) | Time:00:02.05 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.004 1/3 | Packing BVH nodes
# Fra:1 Mem:410.17M (Peak 635.72M) | Time:00:02.06 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.004 1/3 | Packing BVH triangles and strands
# Fra:1 Mem:410.64M (Peak 635.72M) | Time:00:02.06 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.003 2/3 | Building BVH
# Fra:1 Mem:413.46M (Peak 635.72M) | Time:00:02.06 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.003 2/3 | Packing BVH nodes
# Fra:1 Mem:412.28M (Peak 635.72M) | Time:00:02.10 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.003 2/3 | Packing BVH triangles and strands
# Fra:1 Mem:415.56M (Peak 635.72M) | Time:00:02.10 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Geometry BVH Plane.003 2/3 | Packing BVH nodes
# Fra:1 Mem:413.69M (Peak 635.72M) | Time:00:02.11 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Scene BVH | Building
# Fra:1 Mem:413.69M (Peak 635.72M) | Time:00:02.11 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:413.69M (Peak 635.72M) | Time:00:02.11 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:413.69M (Peak 635.72M) | Time:00:02.11 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:443.28M (Peak 635.72M) | Time:00:02.12 | Mem:272.21M, Peak:272.21M | Scene, RenderLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:443.98M (Peak 635.72M) | Time:00:02.13 | Mem:287.01M, Peak:287.01M | Scene, RenderLayer | Updating Mesh | Computing normals
# Fra:1 Mem:450.33M (Peak 635.72M) | Time:00:02.13 | Mem:287.01M, Peak:287.01M | Scene, RenderLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.35M, Peak:293.35M | Scene, RenderLayer | Updating Objects Flags
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.35M, Peak:293.35M | Scene, RenderLayer | Updating Images
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.35M, Peak:293.35M | Scene, RenderLayer | Updating Camera Volume
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.35M, Peak:293.35M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.60M, Peak:293.60M | Scene, RenderLayer | Updating Lights
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.60M, Peak:293.60M | Scene, RenderLayer | Updating Lights | Computing distribution
# Fra:1 Mem:449.62M (Peak 635.72M) | Time:00:02.14 | Mem:293.60M, Peak:293.60M | Scene, RenderLayer | Updating Integrator
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:00:02.14 | Mem:294.88M, Peak:294.88M | Scene, RenderLayer |
| Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3550/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.20 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3551/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.18 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3552/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.15 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3553/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.13 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3554/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.10 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3555/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.08 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3556/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.78 | Remaining:00:01.05 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3557/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.79 | Remaining:00:01.03 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3558/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.79 | Remaining:00:01.00 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3559/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.79 | Remaining:00:00.98 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3560/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.79 | Remaining:00:00.95 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3561/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.79 | Remaining:00:00.93 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3562/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.79 | Remaining:00:00.91 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3563/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.88 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3564/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.86 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3565/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.83 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3566/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.81 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3567/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.78 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3568/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.76 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3569/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.80 | Remaining:00:00.73 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3570/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.81 | Remaining:00:00.71 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3571/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.81 | Remaining:00:00.68 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3572/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.81 | Remaining:00:00.66 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3573/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.81 | Remaining:00:00.63 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3574/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.81 | Remaining:00:00.61 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3575/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.81 | Remaining:00:00.58 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3576/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.56 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3577/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.53 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3578/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.51 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3579/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.48 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3580/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.46 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3581/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.44 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3582/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.82 | Remaining:00:00.41 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3583/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.83 | Remaining:00:00.39 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3584/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.83 | Remaining:00:00.36 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3585/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.83 | Remaining:00:00.34 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3586/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.83 | Remaining:00:00.31 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3587/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.83 | Remaining:00:00.29 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3588/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.83 | Remaining:00:00.26 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3589/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.24 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3590/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.21 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3591/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.19 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3592/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.17 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3593/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.14 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3594/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.12 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3595/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.84 | Remaining:00:00.09 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3596/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.85 | Remaining:00:00.07 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3597/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.85 | Remaining:00:00.04 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3598/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.85 | Remaining:00:00.02 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3599/3600 Tiles, Sample 1000/1000
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.85 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Rendered 3600/3600 Tiles
# Fra:1 Mem:450.90M (Peak 635.72M) | Time:01:29.85 | Mem:294.89M, Peak:294.90M | Scene, RenderLayer | Finished
# Fra:1 Mem:102.44M (Peak 635.72M) | Time:01:29.91 | Compositing
# Fra:1 Mem:102.44M (Peak 635.72M) | Time:01:29.91 | Compositing | Determining resolution
# Fra:1 Mem:102.44M (Peak 635.72M) | Time:01:29.91 | Compositing | Initializing execution
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.92 | Compositing | Tile 1-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.92 | Compositing | Tile 2-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.92 | Compositing | Tile 3-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.92 | Compositing | Tile 4-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 5-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 6-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 7-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 8-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 9-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 10-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.93 | Compositing | Tile 11-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.94 | Compositing | Tile 12-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.94 | Compositing | Tile 13-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.94 | Compositing | Tile 14-15
# Fra:1 Mem:120.08M (Peak 635.72M) | Time:01:29.94 | Compositing | Tile 15-15
# Fra:1 Mem:120.02M (Peak 635.72M) | Time:01:29.94 | Compositing | De-initializing execution
# Saved: 'output/blender-01.png'
#  Time: 01:31.04 (Saving: 00:01.10)
#
#
# Blender quit

# %%
#@title Download the result with the selected method
path, dirs, files_folder = next(os.walk("output"))
output_folder_name = output_name.replace('#', '') + 'render'

if download_type == 'gdrive_direct':
    pass
elif len(files_folder) == 1:
    render_img = 'output/' + files_folder[0]
    if download_type == 'direct':
        files.download('output/' + files_folder[0])
    else:
        shutil.copy('/content/' + render_img, '/drive/My Drive/' + drive_output_path)
elif len(files_folder) > 1:
    if zip_files:
        shutil.make_archive(output_folder_name, 'zip', 'output')
    if download_type == 'direct':
        files.download(output_folder_name + '.zip')
    else:
        shutil.copy('/content/' + output_folder_name + ".zip", '/drive/My Drive/' + drive_output_path)
elif download_type == 'direct':
    for f in files_folder:
        files.download('output/{}'.format(f))
    # Drive, no zip
    else:
        for f in files_folder:
          shutil.copy("/content/output/" + f, '/drive/My Drive/' + drive_output_path + f)
else:
    raise SystemExit("No frames are rendered.")
